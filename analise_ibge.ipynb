# %%
import pandas as pd

# Lendo o arquivo Excel
df = pd.read_excel('Índice e variação do volume de serviços, segundo as atividades de serviços (Brasil - abril 2025).xlsx')

# Visualizando as primeiras linhas
df.head()

# Reimportar o Excel pulando a primeira linha (que tem o título da tabela)
df = pd.read_excel(
    'Índice e variação do volume de serviços, segundo as atividades de serviços (Brasil - abril 2025).xlsx',
    skiprows=1
)

# Exibir as primeiras linhas para verificar
df.head()
# Out:
#                      Atividades de serviços  \
# 0                                     Total
# 1         1. Serviços prestados às famílias
# 2  1.1 Serviços de alojamento e alimentação
# 3                          1.1.1 Alojamento
# 4                         1.1.2 Alimentação
#
#    Índice de volume de serviços (Base: média de 2022 = 100) (Número índice)  \
# 0                                          104.96885
# 1                                          104.89789
# 2                                          106.10195
# 3                                          105.68054
# 4                                          106.21796
#
#    Variação mensal mês / igual mês do ano anterior) do volume de serviços (Base: Igual mês do ano anterior = 100) (Percentual)  \
# 0                                                1.8
# 1                                                4.8
# 2                                                6.4
# 3                                               10.6
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Atividades de serviços', 'Índice de volume de serviços (Base: média de 2022 = 100) (Número índice)', 'Variação mensal mês / igual mês do ano anterior) do volume de serviços (Base: Igual mês do ano anterior = 100) (Percentual)', 'Variação acumulada no ano do volume de serviços (Base: Igual período do ano anterior = 100) (Percentual)', 'Variação acumulada em 12 meses do volume de serviços (Base: 12 meses imediatamente anteriores aos 12 últimos meses = 100) (Percentual)']

# %%
df.columns = ['Servico', 'IndiceVolume', 'VariacaoMensal', 'VariacaoAno', 'Variacao12Meses']

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    data=df,
    x='VariacaoMensal',
    y='Servico',
    palette='viridis'
)

plt.title('Variação Mensal do Volume de Serviços - Abril 2025')
plt.xlabel('Variação Mensal (%)')
plt.ylabel('Tipo de Serviço')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\silva\AppData\Local\Temp\ipykernel_6328\4254435008.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
plt.savefig('variacao_mensal_servicos_abril2025.png', dpi=300, bbox_inches='tight')

# %%
for col in df.columns:
    print(repr(col))
# Out:
# 'Servico'
# 'IndiceVolume'
# 'VariacaoMensal'
# 'VariacaoAno'
# 'Variacao12Meses'

# %%
df.columns = ['Servico', 'IndiceVolume', 'VariacaoMensal', 'VariacaoAno', 'Variacao12Meses']

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    data=df,
    x='VariacaoAno',
    y='Servico',
    palette='crest'
)

plt.title('Variação Acumulada no Ano - Abril 2025')
plt.xlabel('Variação Acumulada (%)')
plt.ylabel('Tipo de Serviço')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\silva\AppData\Local\Temp\ipykernel_6328\600401199.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
plt.savefig('grafico_variacao_acumulada_ano.png', dpi=300, bbox_inches='tight')

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    data=df,
    x='Variacao12Meses',  # Ou o nome original da coluna, se não renomeou
    y='Servico',
    palette='magma'
)

plt.title('Variação Acumulada em 12 Meses - Abril 2025')
plt.xlabel('Variação em 12 Meses (%)')
plt.ylabel('Tipo de Serviço')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\silva\AppData\Local\Temp\ipykernel_6328\2250364689.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    data=df,
    x='Variacao12Meses',
    y='Servico',
    palette='magma'
)

plt.title('Variação Acumulada em 12 Meses - Abril 2025')
plt.xlabel('Variação em 12 Meses (%)')
plt.ylabel('Tipo de Serviço')

# SALVANDO ANTES DE EXIBIR
plt.savefig('grafico_variacao_12_meses.png', dpi=300, bbox_inches='tight')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\silva\AppData\Local\Temp\ipykernel_6328\2902874784.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    data=df,
    x='VariacaoMensal',  # substitua pelo nome correto se não renomeou as colunas
    y='Servico',
    palette='viridis'
)

plt.title('Variação Mensal do Volume de Serviços - Abril 2025')
plt.xlabel('Variação Mensal (%)')
plt.ylabel('Tipo de Serviço')

# Salvar imagem ANTES do show
plt.savefig('grafico_variacao_mensal.png', dpi=300, bbox_inches='tight')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\silva\AppData\Local\Temp\ipykernel_6328\3119337225.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    data=df,
    x='VariacaoAno',
    y='Servico',
    palette='crest'
)

plt.title('Variação Acumulada no Ano - Abril 2025')
plt.xlabel('Variação Acumulada (%)')
plt.ylabel('Tipo de Serviço')

# Salvar imagem ANTES do show
plt.savefig('grafico_variacao_acumulada_ano.png', dpi=300, bbox_inches='tight')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\silva\AppData\Local\Temp\ipykernel_6328\2308628471.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
plt.savefig('grafico_variacao_12_meses.png', dpi=300, bbox_inches='tight')
